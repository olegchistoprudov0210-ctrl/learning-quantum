# %% [markdown]
# <a href="https://colab.research.google.com/github/olegchistoprudov0210-ctrl/learning-quantum/blob/main/05_quantum_dynamics_and_3d_sphere.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qutip

import numpy as np
import qutip as qt
import matplotlib.pyplot as plt

psi0 = qt.basis(2, 1)

b = qt.Bloch()
H = qt.sigmax()
c1 = np.sqrt(0.05) * qt.destroy(2)
c2 = np.sqrt(0.3) * qt.sigmaz()
gamma = 0.2
tlist = np.linspace(0, 20, 200)
c_ops = [c1, c2]

result = qt.mesolve(H, psi0, tlist, c_ops, [qt.sigmax(), qt.sigmay(), qt.sigmaz()])
b.add_points(result.expect)
b.show()
