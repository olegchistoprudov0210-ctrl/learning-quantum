# %% [markdown]
# <a href="https://colab.research.google.com/github/olegchistoprudov0210-ctrl/learning-quantum/blob/main/02_z_gate_phase_filter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

h = 0.707
psi = np.array([h, h])

Z = np.array([
    [1,  0],
    [0, -1]])

psi_new = psi @ Z

print("Phase-shifted state (Result: [0.707, -0.707]):", psi_new)
# Out:
# Phase-shifted state (Result: [0.707, -0.707]): [ 0.707 -0.707]
